# %%
import photon_canon as mc
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patches

# %%
dw = mc.Medium(n=1.33, mu_a=0, mu_s=0, desc='water', display_color='aqua')
g = mc.Medium(n=1.523, mu_a=0, mu_s=0, desc='glass', display_color='gray')
t = mc.Medium(n=1.33, mu_a=5, mu_s=10, g=0.9, desc='tissue', display_color='lightpink')
surroundings_n = 1.33

OD = mc.hardware.OD
ID = mc.hardware.ID
theta = np.arctan(-OD / mc.hardware.WD)

sampler = mc.hardware.ring_pattern((ID, OD), theta)
LED = mc.Illumination(pattern=sampler)
detector = mc.Detector(mc.hardware.cone_of_acceptance(ID))

n = 250
# Out:
# C:\Users\jdivers\PycharmProjects\photon_canon\src\photon_canon\optics.py:48: UserWarning: g is automatically set to 1 where mu_s is 0. Set a non-zero scattering coefficient if a non-unity g value is necessary.
#   warnings.warn('g is automatically set to 1 where mu_s is 0. '

# %% [markdown]
# # Simulation comparisons
# | ID | System               | Tissue thickness | Simulation method | Recursion | Illumination direction | Illumination Incidence | Detector   | Comparison | Notes                                        |
# |:---|:---------------------|:-----------------|:------------------|:----------|:-----------------------|:-----------------------|:-----------|:-----------|:---------------------------------------------|
# | 1  | Tissue               | Inf              | Manual Method     | False     | Normal                 | Origin                 | None       | A          |                                              |
# | 2  | Tissue               | Inf              | Photon Method     | False     | Normal                 | Origin                 | None       | AB         |                                              |
# | 3  | Tissue               | Inf              | Photon Method     | Simple    | Normal                 | Origin                 | None       | BC         |                                              |
# | 4  | Tissue               | Inf              | Photon Method     | Simple    | Oblique                | Origin                 | None       | CD         | Compared direciton sampling in sub-a and -b  |
# | 5  | Tissue               | Inf              | Photon Method     | Simple    | Oblique                | Ring                   | None       | DE         | Compared location sampline in sub-a and -b   |
# | 6  | Tissue               | Inf              | Photon Method     | Simple    | Oblique                | Ring                   | Inner cone | EF         | Compare detection accounting in sub-a and -b |
# | 7  | Water, Tissue        | Inf              | Photon Method     | Simple    | Oblique                | Ring                   | Inner cone | FG         |                                              |
# | 8  | Water, Glass, Tissue | Inf              | Photon Method     | Simple    | Oblique                | Ring                   | Inner cone | GH         |                                              |
# | 9  | Water, Glass, Tissue | 1mm              | Photon Method     | Simple    | Oblique                | Ring                   | Inner cone | GH         |                                              |

# %% [markdown]
# ## Simulation 1

# %%
s = mc.System(
    t, float('inf'),
    surrounding_n=surroundings_n,
    illuminator=LED,
    detector=(detector, 0),
)
print(s)
photon = mc.Photon(650, batch_size=n, system=s, recurse=False, russian_roulette_constant=20)
while not photon.is_terminated:
    photon.absorb()
    photon.move()
    photon.scatter()
photon.plot_path()

print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# C:\Users\jdivers\PycharmProjects\photon_canon\src\photon_canon\optics.py:997: RuntimeWarning: divide by zero encountered in divide
#   step = np.where(mu_t > 0, -np.log(np.random.rand(self.batch_size)) / mu_t, float('inf'))
#  __________________
# |------ -inf ------|
# |-> Surroundings <-|
# |------- 0 --------|
# |->    Tissue    <-|
# |------ inf -------|
#  __________________
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 0.38% of photons reflected
# 99.66% of photons absorbed
# 250 total photons simulated.
# -0.05% overage of photons.

# %% [markdown]
# ## Simulation 2
#
# Using `photon.simulate()` method

# %%
photon = mc.Photon(650, batch_size=n, system=s, recurse=False, russian_roulette_constant=20)
photon.simulate()
photon.plot_path()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 0.49% of photons reflected
# 99.74% of photons absorbed
# 251 total photons simulated.
# -0.23% overage of photons.

# %% [markdown]
# ## Simulation 3
#
# Using recursion

# %%
photon = mc.Photon(650, batch_size=500, system=s, recurse=True, russian_roulette_constant=20)
photon.simulate()
photon.plot_path()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 1.47% of photons reflected
# 198.48% of photons absorbed
# 500 total photons simulated.
# -99.95% overage of photons.

# %% [markdown]
# ## Simulation 4
#
# Using angular incidence
#
# ### 4a
#
# Angle set directly.

# %%
phi = 2 * np.pi * np.random.rand()
dir_cos = np.array([np.sin(theta) * np.cos(phi), np.sin(theta) * np.sin(phi), np.cos(theta)])
photon = mc.Photon(650, batch_size=n, directional_cosines=dir_cos, system=s, recurse=True, russian_roulette_constant=20)
photon.simulate()
photon.plot_path()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 4.43% of photons reflected
# 95.53% of photons absorbed
# 250 total photons simulated.
# 0.04% overage of photons.

# %% [markdown]
# ### 4b
#
# Angle sampled from `sampler()`

# %%
_, direction = sampler(n)
photon = mc.Photon(650, batch_size=n, directional_cosines=direction, system=s, recurse=True, russian_roulette_constant=20)
photon.simulate()
photon.plot_path()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 3.49% of photons reflected
# 96.55% of photons absorbed
# 250 total photons simulated.
# -0.05% overage of photons.

# %% [markdown]
# ## Simulation 5
#
# Using location distribution
#
# ### 5a
#
# location from `sampler()`

# %%
fig = plt.figure(figsize=(14, 14))
ax = np.array([
    fig.add_subplot(2, 2, 1, projection='3d'), fig.add_subplot(2, 2, 2),
    fig.add_subplot(2, 2, 3, projection='3d'), fig.add_subplot(2, 2, 4)
])

location, direction = sampler(n)
photon = mc.Photon(650, batch_size=n, location_coordinates=location, directional_cosines=direction, system=s, recurse=True, russian_roulette_constant=20)
photon.simulate()

photon.plot_path(axes=ax[0])
photon.plot_path(project_onto='xz', axes=[ax[1]])
x,y,z = [photon.location_history[: , i, :2] for i in range(3)]
for i in range(n):
    ax[2].plot(x[i],y[i],z[i])
ax[3].scatter(*photon.location_history[:, :2, 0].T)
ax[2].set_title("Photons' first move")
ax[2].invert_zaxis()
ax[3].set_title("Photons' starting locations")
fig.tight_layout()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 4.13% of photons reflected
# 95.77% of photons absorbed
# 250 total photons simulated.
# 0.10% overage of photons.

# %% [markdown]
# ### 5b
#
# location and direction from `system.beam()`

# %%
fig = plt.figure(figsize=(14, 14))
ax = np.array([
    fig.add_subplot(2, 2, 1, projection='3d'), fig.add_subplot(2, 2, 2), 
    fig.add_subplot(2, 2, 3, projection='3d'), fig.add_subplot(2, 2, 4)
])
photon = s.beam(batch_size=n, recurse=True, russian_roulette_constant=20)
photon.simulate()

photon.plot_path(axes=ax[0])
photon.plot_path(project_onto='xz', axes=[ax[1]])
x,y,z = [photon.location_history[: , i, :2] for i in range(3)]
for i in range(n):
    ax[2].plot(x[i],y[i],z[i])
ax[3].scatter(*photon.location_history[:, :2, 0].T)
ax[2].set_title("Photons' first move")
ax[2].invert_zaxis()
ax[3].set_title("Photons' starting locations")
fig.tight_layout()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 4.19% of photons reflected
# 95.83% of photons absorbed
# 250 total photons simulated.
# -0.02% overage of photons.

# %% [markdown]
# ## Simulation 6
#
# Using detection region
#
# ### 6a
#
# Manually testing for detection

# %%
detected = 0
fig = plt.figure(figsize=(14, 14))
ax = np.array([
    fig.add_subplot(3, 2, 1, projection='3d'), fig.add_subplot(3, 2, 2), 
    fig.add_subplot(3, 2, 3, projection='3d'), fig.add_subplot(3, 2, 4),
    fig.add_subplot(3, 1, 3)
])
photon = s.beam(batch_size=n, recurse=True, russian_roulette_constant=20)
photon.simulate()
exit_r = np.sqrt(photon.exit_location[:, 0] ** 2 + photon.exit_location[:, 1] ** 2)  if photon.exit_location is not None else float('inf')
detected += np.sum(np.where(exit_r < ID, photon.exit_weights, 0))

photon.plot_path(axes=ax[0])
photon.plot_path(project_onto='xz', axes=[ax[1]])
x,y,z = [photon.location_history[: , i, :2] for i in range(3)]
for i in range(n):
    ax[2].plot(x[i],y[i],z[i])
ax[3].scatter(*photon.location_history[:, :2, 0].T)
x,y,_ = photon.exit_location.T if photon.exit_location is not None else [(), (), ()]
ax[4].scatter(x,y)
ax[2].set_title("Photons' first move")
ax[2].invert_zaxis()
ax[3].set_title("Photons' starting locations")
detector_circle = patches.Circle((0,0), ID, edgecolor='black', facecolor='none')
ax[4].add_patch(detector_circle)
ax[4].set_title('Exit locations and detector location')
fig.tight_layout()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:.2f}".format(detected / n * 100) + '% of photons detected ')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 3.61% of photons reflected
# 96.49% of photons absorbed
# 250 total photons simulated.
# 2.09% of photons detected
# -0.10% overage of photons.

# %% [markdown]
# ### 6b
# Built-in detector method

# %%
detector.reset()
fig = plt.figure(figsize=(14, 14))
ax = np.array([
    fig.add_subplot(3, 2, 1, projection='3d'), fig.add_subplot(3, 2, 2), 
    fig.add_subplot(3, 2, 3, projection='3d'), fig.add_subplot(3, 2, 4),
    fig.add_subplot(3, 1, 3)
])

photon = s.beam(batch_size=n, recurse=True, russian_roulette_constant=20)
photon.simulate()

photon.plot_path(axes=ax[0])
photon.plot_path(project_onto='xz', axes=[ax[1]])
x,y,z = [photon.location_history[: , i, :2] for i in range(3)]
for i in range(n):
    ax[2].plot(x[i],y[i],z[i])
ax[3].scatter(*photon.location_history[:, :2, 0].T)
x,y,_ = photon.exit_location.T if photon.exit_location is not None else [(), (), ()]
ax[4].scatter(x,y)
ax[2].set_title("Photons' first move")
ax[2].invert_zaxis()
ax[3].set_title("Photons' starting locations")
detector_circle = patches.Circle((0,0), ID, edgecolor='black', facecolor='none')
ax[4].add_patch(detector_circle)
ax[4].set_title('Exit locations and detector location')
fig.tight_layout()
print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
print("{:.2f}".format(detector.n_detected / n * 100) + '% of photons detected ')
print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))
# Out:
# 0 total internal reflectance events.
# 0.00% of photons transmitted.
# 3.58% of photons reflected
# 96.31% of photons absorbed
# 250 total photons simulated.
# 1.35% of photons detected
# 0.11% overage of photons.

# %%
def make_all_plots(photon, tissue_start=0.2, into_tissue_step=1):
    fig = plt.figure(figsize=(14, 17.5))
    ax = np.array([
        fig.add_subplot(3, 4, 1, projection='3d'), fig.add_subplot(3, 4, 2), fig.add_subplot(3, 4, 3), fig.add_subplot(3, 4, 4),  # 0-3: Paths
        fig.add_subplot(3, 2, 3, projection='3d'), fig.add_subplot(3, 2, 4, projection='3d'),  # 4-5: Illumination pattern (beam in water and beam into tissue)
        fig.add_subplot(3, 2, 5), fig.add_subplot(3, 2, 6)  # 6-7: Incidence/detection at tissue and locations at objective
    ])
    
    photon.plot_path(axes=ax[0])
    photon.plot_path(project_onto='xy', axes=[ax[1]])
    photon.plot_path(project_onto='xz', axes=[ax[2]])
    photon.plot_path(project_onto='yz', axes=[ax[3]])
    
    # First move
    x,y,z = [photon.location_history[: , i, 0:2] for i in range(3)]
    for i in range(n):
        ax[4].plot(x[i],y[i],z[i])
    
    # Second move
    x,y,z = [photon.location_history[: , i, into_tissue_step:into_tissue_step+2] for i in range(3)]
    for i in range(n):
        ax[5].plot(x[i],y[i],z[i])
    
    # Tissue positions
    # Starting point
    ax[6].scatter(*photon.location_history[:, :2, 1].T, color='b', label='Incident locations')
    # Exit locations
    out_of_tissue = photon.location_history[:,2] == tissue_start
    out_of_tissue[:, into_tissue_step] = False  # Ignore entry case
    x, y = np.where(out_of_tissue, [photon.location_history[:, 0], photon.location_history[:, 1]], np.nan)
    ax[6].scatter(x[not np.isnan],y[not np.isnan], color='r', label='Exit locations')
    
    # Objective positions
    # Starting point
    ax[7].scatter(*photon.location_history[:, :2, 0].T, color='b', label='Starting locations')
    # Exit location
    x,y,_ = photon.exit_location.T if photon.exit_location is not None else [(), (), ()]
    ax[7].scatter(x,y, color='r', label='Exit locations')
    
    ax[0].set(xlim=[-0.5, 0.5], ylim=[-0.5, 0.5], zlim=[0.4, -0.01])
    ax[1].set(xlim=[-0.5, 0.5], ylim=[-0.5, 0.5])
    ax[2].set(xlim=[-0.5, 0.5], ylim=[0.8, -0.01])
    ax[3].set(xlim=[-0.5, 0.5], ylim=[0.8, -0.010])
    ax[4].set(xlim=[-0.5, 0.5], ylim=[-0.5, 0.5], zlim=[0, 0.22])
    ax[4].set_title("Photons' move to tissue")
    ax[4].invert_zaxis()
    ax[5].set(xlim=[-0.2, 0.2], ylim=[-0.2, 0.2], zlim=[0.42, 0.2])
    ax[5].set_title("Photons' first step into tissue")
    ax[6].set(xlim=[-0.05, 0.05], ylim=[-0.05, 0.05])
    ax[6].set_title("Photons' incident and detection locations at tissue interface")
    ax[6].legend()
    ax[7].set(xlim=[-0.5, 0.5], ylim=[-0.5, 0.5])
    ax[7].set_title("Photons' incident and detection locations at objective")
    detector_circle = patches.Circle((0, 0), ID, edgecolor='black', facecolor='none', label='Detector region')
    ax[7].add_patch(detector_circle)
    ax[7].set_title('Incident and Exit locations')
    ax[7].legend()
    fig.tight_layout()
    print("{}".format(np.sum(photon.tir_count)) + ' total internal reflectance events.')
    print("{:.2f}".format(photon.T / n * 100) + '% of photons transmitted. ')
    print("{:.2f}".format(photon.R / n * 100) + '% of photons reflected ')
    print("{:.2f}".format(photon.A / n * 100) + '% of photons absorbed ')
    print("{:.0f}".format(sum([photon.T, photon.R, photon.A])) + ' total photons simulated.')
    print("{:.2f}".format((photon.R - detector.n_detected)) + ' photons rejected by detector aperture.')
    print("{:.2f}".format(detector.n_detected / (n - (photon.R - detector.n_detected))  * 100) + '% of photons detected ')
    print("{:0.2f}% overage of photons.".format(100 * (n - sum([photon.T, photon.R, photon.A])) / n))

# %% [markdown]
# ## Simulation 7
# Using system with water layer

# %%
s = mc.System(
    dw, 0.2,
    t, float('inf'),
    surrounding_n=surroundings_n,
    illuminator=LED,
    detector=(detector,0)
)
print(s)

detector.reset()
photon = s.beam(batch_size=n, recurse=True, russian_roulette_constant=20, tir_limit=100)
photon.simulate()
make_all_plots(photon, tissue_start=0.2, into_tissue_step=1)
# Out:
#  __________________
# |------ -inf ------|
# |-> Surroundings <-|
# |------- 0 --------|
# |->    Water     <-|
# |------ 0.2 -------|
# |->    Tissue    <-|
# |------ inf -------|
#  __________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 12
#      10 detector.reset()
#      11 photon = s.beam(batch_size=n, recurse=True, russian_roulette_constant=20, tir_limit=100)
# ---> 12 photon.simulate()
#      13 make_all_plots(photon, tissue_start=0.2, into_tissue_step=1)
#
# File ~\PycharmProjects\photon_canon\src\photon_canon\optics.py:816, in Photon.simulate(self)
#     814 while not self.is_terminated:
#     815     self.absorb()
# --> 816     self.move()
#     817     self.scatter()
#
# File ~\PycharmProjects\photon_canon\src\photon_canon\optics.py:1026, in Photon.move(self, step)
#    1023 self.weights_history = np.append(self.weights_history, self.weights[..., np.newaxis], axis=1)
#    1025 # Check if any new photons exited
# -> 1026 exit_mask = np.equal(self.headed_into(), self.system.surroundings) & (self.weights > 0)
#    1028 if np.any(exit_mask):
#    1029     self.exit_location[exit_mask] = self.location_history[exit_mask, ..., -1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\main.py:1126, in BaseModel.__eq__(self, other)
#    1119     return False
#    1121 # We only want to compare pydantic fields but ignoring fields is costly.
#    1122 # We'll perform a fast check first, and fallback only when needed
#    1123 # See GH-7444 and GH-7825 for rationale and a performance benchmark
#    1124
#    1125 # First, do the fast (and sometimes faulty) __dict__ comparison
# -> 1126 if self.__dict__ == other.__dict__:
#    1127     # If the check above passes, then pydantic fields are equal, we can return early
#    1128     return True
#    1130 # We don't want to trigger unnecessary costly filtering of __dict__ on all unequal objects, so we return
#    1131 # early if there are no keys to ignore (we would just return False later on anyway)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## Simulation 8
# Using system with water and glass

# %%
s = mc.System(
    dw, 0.2,
    g, 0.017,
    t, float('inf'),
    surrounding_n=surroundings_n,
    illuminator=LED,
    detector=(detector,0)
)
print(s)
detector.reset()
photon = s.beam(batch_size=n, recurse=False, russian_roulette_constant=20, tir_limit=100)
photon.simulate()
make_all_plots(photon, tissue_start=0.2 + 0.017, into_tissue_step=2)

# %% [markdown]
# ## Simulation 9
# Finite tissue layer

# %%
s = mc.System(
    dw, 0.2,
    g, 0.017,
    t, 0.1,
    surrounding_n=surroundings_n,
    illuminator=LED,
    detector=(detector, 0)
)
print(s)
detector.reset()
photon = s.beam(batch_size=n, recurse=False, russian_roulette_constant=20, tir_limit=100)
photon.simulate()
make_all_plots(photon, tissue_start=0.2 + 0.017, into_tissue_step=2)
